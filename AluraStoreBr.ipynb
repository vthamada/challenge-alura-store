# %% [markdown]
# <a href="https://colab.research.google.com/github/vthamada/challenge-alura-store/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    faturamento = lojas[i]['Preço'].sum()
    print(f"Faturamento Loja {i + 1}: R${faturamento:.2f}")
# Out:
# Faturamento Loja 1: R$1534509.12
# Faturamento Loja 2: R$1488459.06
# Faturamento Loja 3: R$1464025.03
# Faturamento Loja 4: R$1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    categorias_vendidas = lojas[i]['Categoria do Produto'].value_counts()
    quantidade_total_vendida = lojas[i]['Categoria do Produto'].value_counts().sum()
    categoria_mais_vendida = categorias_vendidas.idxmax()
    categoria_menos_vendida = categorias_vendidas.idxmin()
    print(f"\nCategorias mais vendidas - Loja {i+1}:\n")
    print(categorias_vendidas)
    print(f"\nQuantidade total vendida: {quantidade_total_vendida}")
    print(f"\nCategoria mais vendida: {categoria_mais_vendida}")
    print(f"\nCategoria menos vendida: {categoria_menos_vendida} \n")
# Out:
# Categorias mais vendidas - Loja 1:
#
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64
#
# Quantidade total vendida: 2359
#
# Categoria mais vendida: moveis
#
# Categoria menos vendida: utilidades domesticas
#
#
# Categorias mais vendidas - Loja 2:
#
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
#
# Quantidade total vendida: 2359
#
# Categoria mais vendida: moveis
#
# Categoria menos vendida: utilidades domesticas
#
#
# Categorias mais vendidas - Loja 3:
#
# Categoria do Produto
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    media = lojas[i]['Avaliação da compra'].mean()
    print(f"\nMédia de avaliações - Loja {i+1}: {media:.2f}")
# Out:
# Média de avaliações - Loja 1: 3.98
#
# Média de avaliações - Loja 2: 4.04
#
# Média de avaliações - Loja 3: 4.05
#
# Média de avaliações - Loja 4: 4.00

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    mais_vendido = lojas[i]['Produto'].value_counts().idxmax()
    quantidade_mais_vendido = lojas[i]['Produto'].value_counts().max()
    menos_vendido = lojas[i]['Produto'].value_counts().idxmin()
    quantidade_menos_vendido = lojas[i]['Produto'].value_counts().min()
    print(f"\nProduto mais vendido Loja {i+1}: {mais_vendido} com {quantidade_mais_vendido} unidades")
    print(f"\nProduto menos vendido Loja {i+1}: {menos_vendido} com {quantidade_menos_vendido} unidades")
# Out:
# Produto mais vendido Loja 1: Micro-ondas com 60 unidades
#
# Produto menos vendido Loja 1: Headset com 33 unidades
#
# Produto mais vendido Loja 2: Iniciando em programação com 65 unidades
#
# Produto menos vendido Loja 2: Jogo de tabuleiro com 32 unidades
#
# Produto mais vendido Loja 3: Kit banquetas com 57 unidades
#
# Produto menos vendido Loja 3: Blocos de montar com 35 unidades
#
# Produto mais vendido Loja 4: Cama box com 62 unidades
#
# Produto menos vendido Loja 4: Guitarra com 33 unidades

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    media = lojas[i]['Frete'].mean()
    print(f"\nCusto médio de frete - Loja {i+1}: R${media:.2f}")
# Out:
# Custo médio de frete - Loja 1: R$34.69
#
# Custo médio de frete - Loja 2: R$33.62
#
# Custo médio de frete - Loja 3: R$33.07
#
# Custo médio de frete - Loja 4: R$31.28

# %% [markdown]
# # 6. Gráfico de barras: Faturamento por loja

# %%
import matplotlib.pyplot as plt

faturamentos = [loja['Preço'].sum(), loja2['Preço'].sum(), loja3['Preço'].sum(), loja4['Preço'].sum()]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

plt.figure(figsize=(8, 5))
plt.bar(nomes_lojas, faturamentos, color='blue')
plt.title('Faturamento Total por Loja')
plt.ylabel('Faturamento em R$')
plt.xlabel('Lojas')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Gráfico de Pizza: Vendas por Categoria

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

for i in range(len(lojas)):
  categorias_vendidas = lojas[i]['Categoria do Produto'].value_counts()

  plt.figure(figsize=(6, 6))
  plt.pie(categorias_vendidas.values, labels=categorias_vendidas.index, autopct='%1.1f%%', startangle=140)
  plt.title(f'Categorias Mais Vendidas - {nomes_lojas[i]}')
  plt.tight_layout()
  plt.show()

# %% [markdown]
# # 8. Gráfico de dispersão: Média de Avaliação por Loja

# %%
import matplotlib.pyplot as plt

nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

medias_avaliacoes = [
    loja['Avaliação da compra'].mean(),
    loja2['Avaliação da compra'].mean(),
    loja3['Avaliação da compra'].mean(),
    loja4['Avaliação da compra'].mean()
]

plt.figure(figsize=(7, 5))
plt.scatter(nomes_lojas, medias_avaliacoes, color='mediumspringgreen', s=100)
plt.title('Média de Avaliação por Loja')
plt.ylabel('Nota Média')
plt.ylim(0, 5)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9 - Gráfico de barras horizontal: Produto Mais e Menos Vendido por Loja

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

for i in range(len(lojas)):
    produtos = lojas[i]['Produto'].value_counts()

    mais_vendido = produtos.head(1)
    menos_vendido = produtos.tail(1)

    nomes_produtos = [mais_vendido.index[0], menos_vendido.index[0]]
    quantidades = [mais_vendido.values[0], menos_vendido.values[0]]

    plt.figure(figsize=(7, 4))
    plt.barh(nomes_produtos[::-1], quantidades[::-1], color=['magenta', 'turquoise'])
    plt.title(f'Produto Mais e Menos Vendido - {nomes_lojas[i]}')
    plt.xlabel('Quantidade Vendida')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 10. Gráfico de barras: Frete Médio por loja

# %%
import matplotlib.pyplot as plt

nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

fretes_medios = [
    loja['Frete'].mean(),
    loja2['Frete'].mean(),
    loja3['Frete'].mean(),
    loja4['Frete'].mean()
]

plt.figure(figsize=(7, 5))
plt.bar(nomes_lojas, fretes_medios, color="cyan")
plt.title('Frete Médio por Loja')
plt.ylabel('Valor Médio (R$)')
plt.xlabel('Loja')
plt.tight_layout()
plt.show()
