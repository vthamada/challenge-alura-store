# %% [markdown]
# <a href="https://colab.research.google.com/github/vthamada/challenge-alura-store/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    faturamento = lojas[i]['Preço'].sum()
    print(f"Faturamento Loja {i + 1}: R$ {faturamento:.2f}")
# Out:
# Faturamento Loja 1: R$ 1534509.12
# Faturamento Loja 2: R$ 1488459.06
# Faturamento Loja 3: R$ 1464025.03
# Faturamento Loja 4: R$ 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    categorias_vendidas = lojas[i]['Categoria do Produto'].value_counts()
    quantidade_total_vendida = lojas[i]['Categoria do Produto'].value_counts().sum()
    categoria_mais_vendida = categorias_vendidas.idxmax()
    categoria_menos_vendida = categorias_vendidas.idxmin()
    print(f"\nCategorias mais vendidas - Loja {i+1}:\n")
    print(categorias_vendidas)
    print(f"\nQuantidade total de produtos vendidos: {quantidade_total_vendida}")
    print(f"\nCategoria mais vendida: {categoria_mais_vendida}")
    print(f"\nCategoria menos vendida: {categoria_menos_vendida} \n")
# Out:
# Categorias mais vendidas - Loja 1:
#
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64
#
# Quantidade total de produtos vendidos: 2359
#
# Categoria mais vendida: moveis
#
# Categoria menos vendida: utilidades domesticas
#
#
# Categorias mais vendidas - Loja 2:
#
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
#
# Quantidade total de produtos vendidos: 2359
#
# Categoria mais vendida: moveis
#
# Categoria menos vendida: utilidades domesticas
#
#
# Categorias mais vendidas - Loja 3:
#
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    media = lojas[i]['Avaliação da compra'].mean()
    print(f"\nMédia de avaliações - Loja {i+1}: {media:.2f}")
# Out:
# Média de avaliações - Loja 1: 3.98
#
# Média de avaliações - Loja 2: 4.04
#
# Média de avaliações - Loja 3: 4.05
#
# Média de avaliações - Loja 4: 4.00

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    mais_vendido = lojas[i]['Produto'].value_counts().idxmax()
    quantidade_mais_vendido = lojas[i]['Produto'].value_counts().max()
    menos_vendido = lojas[i]['Produto'].value_counts().idxmin()
    quantidade_menos_vendido = lojas[i]['Produto'].value_counts().min()
    print(f"\nProduto mais vendido na Loja {i+1}: {mais_vendido} com {quantidade_mais_vendido} unidades")
    print(f"\nProduto menos vendido na Loja {i+1}: {menos_vendido} com {quantidade_menos_vendido} unidades")
# Out:
# Produto mais vendido na Loja 1: Micro-ondas com 60 unidades
#
# Produto menos vendido na Loja 1: Headset com 33 unidades
#
# Produto mais vendido na Loja 2: Iniciando em programação com 65 unidades
#
# Produto menos vendido na Loja 2: Jogo de tabuleiro com 32 unidades
#
# Produto mais vendido na Loja 3: Kit banquetas com 57 unidades
#
# Produto menos vendido na Loja 3: Blocos de montar com 35 unidades
#
# Produto mais vendido na Loja 4: Cama box com 62 unidades
#
# Produto menos vendido na Loja 4: Guitarra com 33 unidades

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
lojas = [loja, loja2, loja3, loja4]

for i in range(len(lojas)):
    media = lojas[i]['Frete'].mean()
    print(f"\nCusto médio de frete - Loja {i+1}: R${media:.2f}")
# Out:
# Custo médio de frete - Loja 1: R$34.69
#
# Custo médio de frete - Loja 2: R$33.62
#
# Custo médio de frete - Loja 3: R$33.07
#
# Custo médio de frete - Loja 4: R$31.28

# %% [markdown]
# # 6. Gráfico de barras: Faturamento por loja

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

faturamentos = [loja['Preço'].sum() for loja in lojas]

plt.figure(figsize=(8, 5))
plt.bar(nomes_lojas, faturamentos, color='blue')
plt.title('Faturamento Total por Loja')
plt.ylabel('Faturamento em R$')
plt.xlabel('Lojas')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Gráfico de Pizza: Vendas por Categoria

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

for i in range(len(lojas)):
  categorias_vendidas = lojas[i]['Categoria do Produto'].value_counts()

  plt.figure(figsize=(6, 6))
  plt.pie(categorias_vendidas.values, labels=categorias_vendidas.index, autopct='%1.1f%%', startangle=140)
  plt.title(f'Categorias Mais Vendidas - {nomes_lojas[i]}')
  plt.tight_layout()
  plt.show()

# %% [markdown]
# # 8. Gráfico de dispersão: Média de Avaliação por Loja

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

medias_avaliacoes = [loja['Avaliação da compra'].mean() for loja in lojas]

plt.figure(figsize=(7, 5))
plt.plot(nomes_lojas, medias_avaliacoes, marker='o', color='mediumspringgreen', linewidth=1)
plt.title('Média de Avaliação por Loja')
plt.xlabel('Lojas')
plt.ylabel('Nota Média de Avaliação')
plt.ylim(3.5, 4.5)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9 - Gráfico de barras horizontal: Produto Mais e Menos Vendido por Loja

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

for i in range(len(lojas)):
    produtos = lojas[i]['Produto'].value_counts()

    mais_vendido = produtos.idxmax()
    menos_vendido = produtos.idxmin()

    nomes_produtos = [mais_vendido, menos_vendido]
    quantidades = [produtos[mais_vendido], produtos[menos_vendido]]

    plt.figure(figsize=(7, 4))
    plt.barh(nomes_produtos[::-1], quantidades[::-1], color=['magenta', 'turquoise'])
    plt.title(f'Produto Mais e Menos Vendido - {nomes_lojas[i]}')
    plt.xlabel('Quantidade Vendida')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 10. Gráfico de barras: Frete Médio por loja

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

fretes_medios = [loja['Frete'].mean() for loja in lojas]

plt.figure(figsize=(7, 5))
plt.bar(nomes_lojas, fretes_medios, color="cyan")
plt.title('Frete Médio por Loja')
plt.ylabel('Valor Médio (R$)')
plt.xlabel('Lojas')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 11. Análise de Desempenho Geográfico das Lojas

# %%
import folium
from folium.plugins import HeatMap

lojas = [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

def criar_mapa(loja):
    dados = loja[['lat', 'lon']]
    centro = [dados['lat'].mean(), dados['lon'].mean()]
    mapa = folium.Map(location=centro, zoom_start=5)
    HeatMap(dados, radius=10, blur=15).add_to(mapa)
    return mapa

mapa_loja  = criar_mapa(loja)
mapa_loja2 = criar_mapa(loja2)
mapa_loja3 = criar_mapa(loja3)
mapa_loja4 = criar_mapa(loja4)

mapa_loja3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
cores = ['Purples', 'Blues', 'Reds', 'Greens']

for i in range(4):
    plt.figure(figsize=(7, 6))

    plt.hexbin(lojas[i]['lon'], lojas[i]['lat'],
               gridsize=40,
               cmap=cores[i],
               mincnt=1,
               alpha=0.8)

    plt.title(f'Análise de Desempenho Geográfico – {nomes[i]}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.colorbar(label='Nº de vendas')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 12. Relatório Final – Análise de Desempenho das Lojas da Alura Store
#
# ### Introdução
#
# Este relatório visa analisar o desempenho de quatro lojas da rede Alura Store com base em dados de preço, frete, produtos e avaliações. O objetivo da análise é auxiliar o Senhor João a identificar a loja com menor performance entre as quatro lojas e assim ajudá-lo na decisão de venda da que possuir a menor eficiência.
#
# As análises foram realizadas avaliando os seguintes critérios:
#
# - Faturamento total das lojas
# - Categorias de produtos mais e menos vendidos
# - Avaliação média dos clientes
# - Produtos mais e menos vendidos
# - Frete médio praticado
# - Distribuição geográfica das vendas
#
# \\
# ### Faturamento Total
#
# Os resultados obtidos do faturamento das quatro lojas pode ser visto a seguir:
#
# - Faturamento Loja 1: R$ 1534509,12
#
# - Faturamento Loja 2: R$ 1488459,06
#
# - Faturamento Loja 3: R$ 1464025,03
#
# - Faturamento Loja 4: R$ 1384497,58
#
# É possível notar que dentre as quatro lojas a loja 4 foi a que obteve o pior faturamento, com uma diferença significativa em relação as outras.
#
#
# \\
# ### Vendas por Categoria
#
# Abaixo estão os dados referentes a distribuição de vendas entre as categorias de cada loja:
#
# Categorias mais vendidas - Loja 1:
#
# Categoria do Produto
#
# -- moveis: 465
#
# -- eletronicos: 448
#
# -- brinquedos: 324
#
# -- eletrodomesticos: 312
#
# -- esporte e lazer: 284
#
# -- instrumentos musicais: 182
#
# -- livros: 173
#
# -- utilidades domesticas: 171
#
# - Quantidade total de produtos vendidos: 2359
#
# - Categoria mais vendida: moveis
#
# - Categoria menos vendida: utilidades domesticas
#
# ---
# Categorias mais vendidas - Loja 2:
#
# Categoria do Produto
#
# -- moveis: 442
#
# -- eletronicos: 422
#
# -- brinquedos: 313
#
# -- eletrodomesticos: 305
#
# -- esporte e lazer: 275
#
# -- instrumentos musicais: 224
#
# -- livros: 197
#
# -- utilidades domesticas: 181
#
# - Quantidade total de produtos vendidos: 2359
#
# - Categoria mais vendida: moveis
#
# - Categoria menos vendida: utilidades domesticas
#
# ---
#
# Categorias mais vendidas - Loja 3:
#
# Categoria do Produto
#
# -- moveis: 499
#
# -- eletronicos: 451
#
# -- brinquedos: 315
#
# -- eletrodomesticos: 278
#
# -- esporte e lazer: 277
#
# -- livros: 185
#
# -- instrumentos musicais: 177
#
# -- utilidades domesticas: 177
#
# - Quantidade total de produtos vendidos: 2359
#
# - Categoria mais vendida: moveis
#
# - Categoria menos vendida: instrumentos musicais
#
# ---
#
# Categorias mais vendidas - Loja 4:
#
# Categoria do Produto
#
# -- moveis: 480
#
# -- eletronicos: 451
#
# -- brinquedos: 338
#
# -- esporte e lazer: 277
#
# -- eletrodomesticos: 254
#
# -- utilidades domesticas: 201
#
# -- livros: 187
#
# -- instrumentos musicais: 170
#
# - Quantidade total de produtos vendidos: 2358
#
# - Categoria mais vendida: moveis
#
# - Categoria menos vendida: instrumentos musicais
#
# ---
#
# Com base nos dados observa-se que ambas as lojas tiveram uma distribuição de vendas parecida nas categorias, com as lojas 1, 2 e 3 tendo a mesma quantidade total de unidades vendidas e só a loja 4 com uma unidade a menos. Por meio desse critério apenas não é possivel definir qual loja obteve o menor desempenho.
#
# \\
# ### Avaliação Média dos Clientes
#
# A seguir é demonstrado a média de avaliação das lojas:
#
# -- Média de avaliações - Loja 1: 3.98
#
# -- Média de avaliações - Loja 2: 4.04
#
# -- Média de avaliações - Loja 3: 4.05
#
# -- Média de avaliações - Loja 4: 4.00
#
# - A Loja 3 teve a melhor avaliação média, o que aponta para maior satisfação dos clientes.
# - A Loja 1 ficou com a pior avaliação média seguido da loja 4. Porém entre as lojas a loja 1 foi a que obteve um faturamento maior, o que deixa a loja 4 em desvantagem tanto em questão do faturamento, que foi a pior entre as quatro, e em avaliação média.
#
# \\
# ### Produtos Mais e Menos Vendidos
#
# Abaixo encontra-se os dados dos produtos mais e menos vendidos das lojas:
#
# -- Produto mais vendido na Loja 1: Micro-ondas com 60 unidades
#
# -- Produto menos vendido na Loja 1: Headset com 33 unidades
#
# ---
#
# -- Produto mais vendido na Loja 2: Iniciando em programação com 65 unidades
#
# -- Produto menos vendido na Loja 2: Jogo de tabuleiro com 32 unidades
#
# ---
#
# -- Produto mais vendido na Loja 3: Kit banquetas com 57 unidades
#
# -- Produto menos vendido na Loja 3: Blocos de montar com 35 unidades
#
# ---
#
# -- Produto mais vendido na Loja 4: Cama box com 62 unidades
#
# -- Produto menos vendido na Loja 4: Guitarra com 33 unidades
#
# ---
#
#
# - Em todas as lojas, alguns produtos se destacaram em volume de vendas. Novamente este não é um critério que possa avaliar o desempenho das lojas visto que ambas tiveram quantidades aproximadas tanto em produtos mais vendidos quanto produtos menos vendidos. A única diferenciação entre elas foi o tipo de produto vendido.
#
# \\
# ### Frete Médio
#
# A seguir estão os dados referente ao custo médio de frete das lojas:
#
# -- Custo médio de frete - Loja 1: R$ 34,69
#
# -- Custo médio de frete - Loja 2: R$ 33,62
#
# -- Custo médio de frete - Loja 3: R$ 33,07
#
# -- Custo médio de frete - Loja 4: R$ 31,28
#
# - Dentre as lojas, a Loja 4 teve o frete mais barato, mas isso não se refletiu em vantagens competitivas ou aumento nas vendas visto que seu faturamento e sua média de avaliação foram baixas.
#
#
# \\
# ## Conclusão
#
# Com base nas análises realizadas, conclui-se que a Loja 4 apresenta o menor desempenho entre as lojas avaliadas, pois ela possui:
#
# - O Menor faturamento
# - Uma das menores avaliações médias dos clientes
#
# Nos demais critérios como frete, variedade de produtos e categorias vendidas a Loja 4 se manteve em níveis similares às outras lojas, não havendo diferença expressiva. No entanto, o baixo faturamento e a avaliação abaixo da média compromete seu desempenho geral. O Senhor João deve considerar a venda da Loja 4, pois ela representa a menor performance entre as quatro lojas e possui o menor potencial de crescimento comparado às demais.
